# %% [markdown]
# # A description of the data and how it will be used to solve the problem #

# %% [markdown]
# ***Using API Foursquare by the explore endpoint we search for venues nearby the defined 2 appartments - one in Warsaw and other one in Paris.
# Using geolocator we can find the exact location of these 2 appartments.We convert json file to DataFrame and we prepere data.
# Using Folium we create maps containing markers with restaurant - each color correspond to different kind of restaurant. They are distinguished by the country.
# Using Matplotlip we create pie plots to see the percentage of each kind of restaurants. At the end, we create bar charts for both location - in order to compare surroundings.
# Based on that we can decide which appartment is better located taking into account nearby restaurants.***
